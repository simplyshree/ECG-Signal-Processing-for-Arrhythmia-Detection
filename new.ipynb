# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mondejar/mitbih-database")

print("Path to dataset files:", path)
# Out:
# Resuming download from 59768832 bytes (242540056 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/mondejar/mitbih-database?dataset_version_number=2 (59768832/302308888) bytes left.
# 100%|██████████| 288M/288M [01:46<00:00, 2.28MB/s]
# Extracting files...
# Path to dataset files: C:\Users\shree\.cache\kagglehub\datasets\mondejar\mitbih-database\versions\2

# %%
print(os.listdir(path))
print("Dataset path",path)
# Out:
# ['100.csv', '100annotations.txt', '101.csv', '101annotations.txt', '102.csv', '102annotations.txt', '103.csv', '103annotations.txt', '104.csv', '104annotations.txt', '105.csv', '105annotations.txt', '106.csv', '106annotations.txt', '107.csv', '107annotations.txt', '108.csv', '108annotations.txt', '109.csv', '109annotations.txt', '111.csv', '111annotations.txt', '112.csv', '112annotations.txt', '113.csv', '113annotations.txt', '114.csv', '114annotations.txt', '115.csv', '115annotations.txt', '116.csv', '116annotations.txt', '117.csv', '117annotations.txt', '118.csv', '118annotations.txt', '119.csv', '119annotations.txt', '121.csv', '121annotations.txt', '122.csv', '122annotations.txt', '123.csv', '123annotations.txt', '124.csv', '124annotations.txt', '200.csv', '200annotations.txt', '201.csv', '201annotations.txt', '202.csv', '202annotations.txt', '203.csv', '203annotations.txt', '205.csv', '205annotations.txt', '207.csv', '207annotations.txt', '208.csv', '208annotations.txt', '209.cs
# ...

# %%
print(os.getcwd())
# Out:
# c:\Users\shree\Desktop\Python\Arrhythmia-Detection

# %%
os.chdir(path)

# %%
print(os.listdir())
# Out:
# ['100.csv', '100annotations.txt', '101.csv', '101annotations.txt', '102.csv', '102annotations.txt', '103.csv', '103annotations.txt', '104.csv', '104annotations.txt', '105.csv', '105annotations.txt', '106.csv', '106annotations.txt', '107.csv', '107annotations.txt', '108.csv', '108annotations.txt', '109.csv', '109annotations.txt', '111.csv', '111annotations.txt', '112.csv', '112annotations.txt', '113.csv', '113annotations.txt', '114.csv', '114annotations.txt', '115.csv', '115annotations.txt', '116.csv', '116annotations.txt', '117.csv', '117annotations.txt', '118.csv', '118annotations.txt', '119.csv', '119annotations.txt', '121.csv', '121annotations.txt', '122.csv', '122annotations.txt', '123.csv', '123annotations.txt', '124.csv', '124annotations.txt', '200.csv', '200annotations.txt', '201.csv', '201annotations.txt', '202.csv', '202annotations.txt', '203.csv', '203annotations.txt', '205.csv', '205annotations.txt', '207.csv', '207annotations.txt', '208.csv', '208annotations.txt', '209.cs
# ...

# %%
df = pd.read_csv(os.path.join(path, "101.csv"))

for col in df.columns:
    print(repr(col))
# Out:
# "'sample #'"
# "'MLII'"
# "'V1'"

# %%
def load_ecg(csv_path):
    df = pd.read_csv(csv_path)

    signal = df["'MLII'"].values

    return signal

# %%
import pandas as pd

df = pd.read_csv(os.path.join(path, "101.csv"))
print(df.columns)
# Out:
# Index([''sample #'', ''MLII'', ''V1''], dtype='object')

# %%
csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
print(csv_files)
# Out:
# ['100.csv', '101.csv', '102.csv', '103.csv', '104.csv', '105.csv', '106.csv', '107.csv', '108.csv', '109.csv', '111.csv', '112.csv', '113.csv', '114.csv', '115.csv', '116.csv', '117.csv', '118.csv', '119.csv', '121.csv', '122.csv', '123.csv', '124.csv', '200.csv', '201.csv', '202.csv', '203.csv', '205.csv', '207.csv', '208.csv', '209.csv', '210.csv', '212.csv', '213.csv', '214.csv', '215.csv', '217.csv', '219.csv', '220.csv', '221.csv', '222.csv', '223.csv', '228.csv', '230.csv', '231.csv', '232.csv', '233.csv', '234.csv']

# %%
#   file_path = os.path.join(path, csv_file)
#    df = pd.read_csv(file_path)
#
 #   print(csv_file,df.shape)

# %%
patient_id = int(csv_file.replace('.csv',''))

# %%
ann_file = f"{patient_id}annotations.txt"
ann_path = os.path.join(path,ann_file)

# %%
all_data = []

csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]

for csv_file in csv_files:
    patient_id = int(csv_file.replace('.csv',''))

    csv_path = os.path.join(path,csv_file)
    ann_path = os.path.join(path,f"{patient_id}annotations.txt")

    if not os.path.exists(ann_path):
        print("No annotation available")
        continue

    df_patient = process_patient(
        patient_id = patient_id,
        csv_path = csv_path,
        ann_path= ann_path
    )

all_data.append(df_patient)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 15
#      12         print("No annotation available")
#      13         continue
# ---> 15     df_patient = process_patient(
#      16         patient_id = patient_id,
#      17         csv_path = csv_path,
#      18         ann_path= ann_path
#      19     )
#      21 all_data.append(df_patient)
#
# NameError: name 'process_patient' is not defined
